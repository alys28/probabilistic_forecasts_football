# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import process_data

# %%
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)

# %%
interpolated_dir = os.path.join(parent_dir, "dataset_interpolated_with_overtime")

# %%
interpolated_dir = os.path.join(parent_dir, "dataset_interpolated_with_overtime")
training_data = process_data.load_training_data(interpolated_dir)
# Out:
# Loading data for 2022
# Loading data for 2024
# skipping  2024
# Loading data for 2023
# skipping  2023
# Loading data for .DS_Store
# Loading data for 2019
# Loading data for 2021
# Loading data for 2020
# Loading data for 2018

# %%
features = ["home_win", "relative_strength", "homeScore", "awayScore", "scoringPlay", "start.down", "start.distance", "start.yardLine", "end.down", "end.distance", "end.yardLine", "home_timeouts_left", "away_timeouts_left", "home_has_possession"]
#     # Find rows that have NaN values for my array of features
#     rows = training_data[timestep]
#     # Get all rows such that one of the features is NaN
#     rows_with_nan = [row for row in rows if any(np.isnan(row[feature]) for feature in features)]
#     # Print row with NaN values + timestep
#     if len(rows_with_nan) > 0:
#         print("Timestep:", timestep)
#         for row in rows_with_nan:
#             print(row)

# %%
count = 0
for timestep in training_data.keys():
    rows = training_data[timestep]
    
    # Replace NaN values with 0
    for row in rows:
        for feature in features:
            if np.isnan(row[feature]):
                count += 1
                row[feature] = 0
count
# Out:
# 18

# %%
features_data = process_data.feature_selection(training_data, features)

# %%
# Boosted decision tree for classification
from sklearn.ensemble import RandomForestClassifier

models = process_data.setup_models(features_data, RandomForestClassifier, n_estimators=100, max_depth=15, random_state=0)
# Out:
# Training for timestep 0.0
# Training for timestep 0.005
# Training for timestep 0.01
# Training for timestep 0.015
# Training for timestep 0.02
# Training for timestep 0.025
# Training for timestep 0.03
# Training for timestep 0.035
# Training for timestep 0.04
# Training for timestep 0.045
# Training for timestep 0.05
# Training for timestep 0.055
# Training for timestep 0.06
# Training for timestep 0.065
# Training for timestep 0.07
# Training for timestep 0.075
# Training for timestep 0.08
# Training for timestep 0.085
# Training for timestep 0.09
# Training for timestep 0.095
# Training for timestep 0.1
# Training for timestep 0.105
# Training for timestep 0.11
# Training for timestep 0.115
# Training for timestep 0.12
# Training for timestep 0.125
# Training for timestep 0.13
# Training for timestep 0.135
# Training for timestep 0.14
# Training for timestep 0.145
# Training for timestep 0.15
# Training for timestep 0.155
# Training for timestep 0.16
# Training for timestep 0.165
# Training for timestep 0.17
# Training for timestep 0.175
# Training for timestep 0.18
# Training for timestep 0.185
# Training for timestep 0.19
# Training for timestep 0.195
# Training for timestep 0.2
# Training for timestep 0.205
# Training for timestep 0.21
# Training for timestep 0.215
# Training for timestep 0.22
# Training for timestep 0.225
# Training for timestep 0.23
# Training for timestep 0.235
# Training for timestep 0.24
# Training for timestep 0.245
# Training for timestep 0.25
# Training for timestep 0.255
# Training for timestep 0.26
# Training for timestep 0.265
# Training for timestep 0.27
# Training for timestep 0.275
# Training for timestep 0.28
# Training for timestep 0.285
# Training for timestep 0.29
# Training for timestep 0.295
# Training for timestep 0.3
# Training for timestep 0.305
# Training for timestep 0.31
# Training for timestep 0.315
# Training for timestep 0.32
# Training for timestep 0.325
# Training for timestep 0.33
# Training for timestep 0.335
# Training for timestep 0.34
# Training for timestep 0.345
# Training for timestep 0.35
# Training for timestep 0.355
# Training for timestep 0.36
# Training for timestep 0.365
# Training for timestep 0.37
# Training for timestep 0.375
# Training for timestep 0.38
# Training for timestep 0.385
# Training for timestep 0.39
# Training for timestep 0.395
# Training for timestep 0.4
# Training for timestep 0.405
# Training for timestep 0.41
# Training for timestep 0.415
# Training for timestep 0.42
# Training for timestep 0.425
# Training for timestep 0.43
# Training for timestep 0.435
# Training for timestep 0.44
# Training for timestep 0.445
# Training for timestep 0.45
# Training for timestep 0.455
# Training for timestep 0.46
# Training for timestep 0.465
# Training for timestep 0.47
# Training for timestep 0.475
# Training for timestep 0.48
# Training for timestep 0.485
# Training for timestep 0.49
# Training for timestep 0.495
# Training for timestep 0.5
# Training for timestep 0.505
# Training for timestep 0.51
# Training for timestep 0.515
# Training for timestep 0.52
# Training for timestep 0.525
# Training for timestep 0.53
# Training for timestep 0.535
# Training for timestep 0.54
# Training for timestep 0.545
# Training for timestep 0.55
# Training for timestep 0.555
# Training for timestep 0.56
# Training for timestep 0.5650000000000001
# Training for timestep 0.5700000000000001
# Training for timestep 0.5750000000000001
# Training for timestep 0.58
# Training for timestep 0.585
# Training for timestep 0.59
# Training for timestep 0.595
# Training for timestep 0.6
# Training for timestep 0.605
# Training for timestep 0.61
# Training for timestep 0.615
# Training for timestep 0.62
# Training for timestep 0.625
# Training for timestep 0.63
# Training for timestep 0.635
# Training for timestep 0.64
# Training for timestep 0.645
# Training for timestep 0.65
# Training for timestep 0.655
# Training for timestep 0.66
# Training for timestep 0.665
# Training for timestep 0.67
# Training for timestep 0.675
# Training for timestep 0.68
# Training for timestep 0.685
# Training for timestep 0.6900000000000001
# Training for timestep 0.6950000000000001
# Training for timestep 0.7000000000000001
# Training for timestep 0.705
# Training for timestep 0.71
# Training for timestep 0.715
# Training for timestep 0.72
# Training for timestep 0.725
# Training for timestep 0.73
# Training for timestep 0.735
# Training for timestep 0.74
# Training for timestep 0.745
# Training for timestep 0.75
# Training for timestep 0.755
# Training for timestep 0.76
# Training for timestep 0.765
# Training for timestep 0.77
# Training for timestep 0.775
# Training for timestep 0.78
# Training for timestep 0.785
# Training for timestep 0.79
# Training for timestep 0.795
# Training for timestep 0.8
# Training for timestep 0.805
# Training for timestep 0.81
# Training for timestep 0.8150000000000001
# Training for timestep 0.8200000000000001
# Training for timestep 0.8250000000000001
# Training for timestep 0.8300000000000001
# Training for timestep 0.835
# Training for timestep 0.84
# Training for timestep 0.845
# Training for timestep 0.85
# Training for timestep 0.855
# Training for timestep 0.86
# Training for timestep 0.865
# Training for timestep 0.87
# Training for timestep 0.875
# Training for timestep 0.88
# Training for timestep 0.885
# Training for timestep 0.89
# Training for timestep 0.895
# Training for timestep 0.9
# Training for timestep 0.905
# Training for timestep 0.91
# Training for timestep 0.915
# Training for timestep 0.92
# Training for timestep 0.925
# Training for timestep 0.93
# Training for timestep 0.935
# Training for timestep 0.94
# Training for timestep 0.945
# Training for timestep 0.95
# Training for timestep 0.955
# Training for timestep 0.96
# Training for timestep 0.965
# Training for timestep 0.97
# Training for timestep 0.975
# Training for timestep 0.98
# Training for timestep 0.985
# Training for timestep 0.99
# Training for timestep 0.995
# Training for timestep 1.0

# %%
import importlib
importlib.reload(process_data)

# %%
# %reload_ext process_data
test_folders = process_data.load_test_data(interpolated_dir)
# Out:
# Loading data for 2022
# Loading data for 2024
# Loading data for 2023
# Loading data for 2019
# Loading data for 2021
# Loading data for 2020
# Loading data for 2018

# %%
features_test_data = {key: process_data.test_feature_selection(test_data, features) for key, test_data in zip(test_folders.keys(), test_folders.values())}

# %%
X_tests = [features_test_data[year] for year in features_test_data]
merged = {}
for d in X_tests:
    merged.update(d)
X_tests = merged
new_X_tests = {}
print(len(X_tests))
for file in X_tests:
   timestep = 0
   for i in range(len(X_tests[file])):
        if timestep not in new_X_tests:
           new_X_tests[timestep] = [X_tests[file][i]]
        else:
            new_X_tests[timestep] += [X_tests[file][i]]
        timestep += 0.005
X_tests = new_X_tests
# len(X_tests[0.1])
X_tests.keys()
# Out:
# 544
# dict_keys([0, 0.005, 0.01, 0.015, 0.02, 0.025, 0.030000000000000002, 0.035, 0.04, 0.045, 0.049999999999999996, 0.05499999999999999, 0.05999999999999999, 0.06499999999999999, 0.06999999999999999, 0.075, 0.08, 0.085, 0.09000000000000001, 0.09500000000000001, 0.10000000000000002, 0.10500000000000002, 0.11000000000000003, 0.11500000000000003, 0.12000000000000004, 0.12500000000000003, 0.13000000000000003, 0.13500000000000004, 0.14000000000000004, 0.14500000000000005, 0.15000000000000005, 0.15500000000000005, 0.16000000000000006, 0.16500000000000006, 0.17000000000000007, 0.17500000000000007, 0.18000000000000008, 0.18500000000000008, 0.19000000000000009, 0.1950000000000001, 0.2000000000000001, 0.2050000000000001, 0.2100000000000001, 0.2150000000000001, 0.2200000000000001, 0.22500000000000012, 0.23000000000000012, 0.23500000000000013, 0.24000000000000013, 0.24500000000000013, 0.2500000000000001, 0.2550000000000001, 0.2600000000000001, 0.2650000000000001, 0.27000000000000013, 0.27500000000000013, 0.28000000000000014, 0.28500000000000014, 0.29000000000000015, 0.29500000000000015, 0.30000000000000016, 0.30500000000000016, 0.31000000000000016, 0.31500000000000017, 0.3200000000000002, 0.3250000000000002, 0.3300000000000002, 0.3350000000000002, 0.3400000000000002, 0.3450000000000002, 0.3500000000000002, 0.3550000000000002, 0.3600000000000002, 0.3650000000000002, 0.3700000000000002, 0.3750000000000002, 0.3800000000000002, 0.38500000000000023, 0.39000000000000024, 0.39500000000000024, 0.40000000000000024, 0.40500000000000025, 0.41000000000000025, 0.41500000000000026, 0.42000000000000026, 0.42500000000000027, 0.43000000000000027, 0.4350000000000003, 0.4400000000000003, 0.4450000000000003, 0.4500000000000003, 0.4550000000000003, 0.4600000000000003, 0.4650000000000003, 0.4700000000000003, 0.4750000000000003, 0.4800000000000003, 0.4850000000000003, 0.4900000000000003, 0.49500000000000033, 0.5000000000000003, 0.5050000000000003, 0.5100000000000003, 0.5150000000000003, 0.5200000000000004, 0.5250000000000004, 0.5300000000000004, 0.5350000000000004, 0.5400000000000004, 0.5450000000000004, 0.5500000000000004, 0.5550000000000004, 0.5600000000000004, 0.5650000000000004, 0.5700000000000004, 0.5750000000000004, 0.5800000000000004, 0.5850000000000004, 0.5900000000000004, 0.5950000000000004, 0.6000000000000004, 0.6050000000000004, 0.6100000000000004, 0.6150000000000004, 0.6200000000000004, 0.6250000000000004, 0.6300000000000004, 0.6350000000000005, 0.6400000000000005, 0.6450000000000005, 0.6500000000000005, 0.6550000000000005, 0.6600000000000005, 0.6650000000000005, 0.6700000000000005, 0.6750000000000005, 0.6800000000000005, 0.6850000000000005, 0.6900000000000005, 0.6950000000000005, 0.7000000000000005, 0.7050000000000005, 0.7100000000000005, 0.7150000000000005, 0.7200000000000005, 0.7250000000000005, 0.7300000000000005, 0.7350000000000005, 0.7400000000000005, 0.7450000000000006, 0.7500000000000006, 0.7550000000000006, 0.7600000000000006, 0.7650000000000006, 0.7700000000000006, 0.7750000000000006, 0.7800000000000006, 0.7850000000000006, 0.7900000000000006, 0.7950000000000006, 0.8000000000000006, 0.8050000000000006, 0.8100000000000006, 0.8150000000000006, 0.8200000000000006, 0.8250000000000006, 0.8300000000000006, 0.8350000000000006, 0.8400000000000006, 0.8450000000000006, 0.8500000000000006, 0.8550000000000006, 0.8600000000000007, 0.8650000000000007, 0.8700000000000007, 0.8750000000000007, 0.8800000000000007, 0.8850000000000007, 0.8900000000000007, 0.8950000000000007, 0.9000000000000007, 0.9050000000000007, 0.9100000000000007, 0.9150000000000007, 0.9200000000000007, 0.9250000000000007, 0.9300000000000007, 0.9350000000000007, 0.9400000000000007, 0.9450000000000007, 0.9500000000000007, 0.9550000000000007, 0.9600000000000007, 0.9650000000000007, 0.9700000000000008, 0.9750000000000008, 0.9800000000000008, 0.9850000000000008, 0.9900000000000008, 0.9950000000000008, 1.0000000000000007])

# %%
process_data.plot(models, X_tests)

# %%
process_data.write_predictions(models, features_test_data, interpolated_dir, "random_forest_phat_b_2")
# Out:
# 2024
# Finished writing to game_401671629.csv
# Finished writing to game_401671601.csv
# Finished writing to game_401671826.csv
# Finished writing to game_401671832.csv
# Finished writing to game_401671749.csv
# Finished writing to game_401671775.csv
# Finished writing to game_401671761.csv
# Finished writing to game_401671760.csv
# Finished writing to game_401671774.csv
# Finished writing to game_401671748.csv
# Finished writing to game_401671833.csv
# Finished writing to game_401671827.csv
# Finished writing to game_401671600.csv
# Finished writing to game_401671628.csv
# Finished writing to game_401671616.csv
# Finished writing to game_401671831.csv
# Finished writing to game_401671825.csv
# Finished writing to game_401671819.csv
# Finished writing to game_401671762.csv
# Finished writing to game_401671776.csv
# Finished writing to game_401671789.csv
# Finished writing to game_401671788.csv
# Finished writing to game_401671777.csv
# Finished writing to game_401671763.csv
# Finished writing to game_401671818.csv
# Finished writing to game_401671824.csv
# Finished writing to game_401671830.csv
# Finished writing to game_401671617.csv
# Finished writing to game_401671808.csv
# Finished writing to game_401671834.csv
# Finished writing to game_401671820.csv
# Finished writing to game_401671767.csv
# Finished writing to game_401671773.csv
# Finished writing to game_401671798.csv
# Finished writing to game_401671799.csv
# Finished writing to game_401671772.csv
# Finished writing to game_401671766.csv
# Finished writing to game_401671821.csv
# Finished writing to game_401671835.csv
# Finished writing to game_401671809.csv
# Finished writing to game_401671638.csv
# Finished writing to game_401671823.csv
# Finished writing to game_401671837.csv
# Finished writing to game_401671599.csv
# Finished writing to game_401671770.csv
# Finished writing to game_401671764.csv
# Finished writing to game_401671721.csv
# Finished writing to game_401671709.csv
# Finished writing to game_401671494.csv
# Finished writing to game_401671682.csv
# Finished writing to game_401671696.csv
# Finished writing to game_401671866.csv
# Finished writing to game_401671872.csv
# Finished writing to game_401671641.csv
# Finished writing to game_401671655.csv
# Finished writing to game_401671669.csv
# Finished writing to game_401671651.csv
# Finished writing to game_401671645.csv
# Finished writing to game_401671679.csv
# Finished writing to game_401671692.csv
# Finished writing to game_401671686.csv
# Finished writing to game_401671876.csv
# Finished writing to game_401671862.csv
# Finished writing to game_401671490.csv
# Finished writing to game_401671725.csv
# Finished writing to game_401671731.csv
# Finished writing to game_401671719.csv
# Finished writing to game_401671718.csv
# Finished writing to game_401671730.csv
# Finished writing to game_401671724.csv
# Finished writing to game_401671491.csv
# Finished writing to game_401671863.csv
# Finished writing to game_401671877.csv
# Finished writing to game_401671687.csv
# Finished writing to game_401671693.csv
# Finished writing to game_401671678.csv
# Finished writing to game_401671644.csv
# Finished writing to game_401671650.csv
# Finished writing to game_401671646.csv
# Finished writing to game_401671652.csv
# Finished writing to game_401671685.csv
# Finished writing to game_401671849.csv
# Finished writing to game_401671691.csv
# Finished writing to game_401671861.csv
# Finished writing to game_401671875.csv
# Finished writing to game_401671493.csv
# Finished writing to game_401671732.csv
# Finished writing to game_401671726.csv
# Finished writing to game_401671727.csv
# Finished writing to game_401671733.csv
# Finished writing to game_401671492.csv
# Finished writing to game_401671874.csv
# Finished writing to game_401671860.csv
# Finished writing to game_401671690.csv
# Finished writing to game_401671848.csv
# Finished writing to game_401671684.csv
# Finished writing to game_401671653.csv
# Finished writing to game_401671647.csv
# Finished writing to game_401671620.csv
# Finished writing to game_401671634.csv
# Finished writing to game_401671807.csv
# Finished writing to game_401671813.csv
# Finished writing to game_401671768.csv
# Finished writing to game_401671754.csv
# Finished writing to game_401671740.csv
# Finished writing to game_401671797.csv
# Finished writing to game_401671783.csv
# Finished writing to game_401671782.csv
# Finished writing to game_401671796.csv
# Finished writing to game_401671741.csv
# Finished writing to game_401671755.csv
# Finished writing to game_401671769.csv
# Finished writing to game_401671812.csv
# Finished writing to game_401671806.csv
# Finished writing to game_401671635.csv
# Finished writing to game_401671621.csv
# Finished writing to game_401671637.csv
# Finished writing to game_401671623.csv
# Finished writing to game_401671810.csv
# Finished writing to game_401671804.csv
# Finished writing to game_401671838.csv
# Finished writing to game_401671743.csv
# Finished writing to game_401671757.csv
# Finished writing to game_401671780.csv
# Finished writing to game_401671794.csv
# Finished writing to game_401671795.csv
# Finished writing to game_401671781.csv
# Finished writing to game_401671756.csv
# Finished writing to game_401671742.csv
# Finished writing to game_401671839.csv
# Finished writing to game_401671805.csv
# Finished writing to game_401671811.csv
# Finished writing to game_401671622.csv
# Finished writing to game_401671636.csv
# Finished writing to game_401671632.csv
# Finished writing to game_401671626.csv
# Finished writing to game_401671829.csv
# Finished writing to game_401671815.csv
# Finished writing to game_401671801.csv
# Finished writing to game_401671746.csv
# Finished writing to game_401671752.csv
# Finished writing to game_401671785.csv
# Finished writing to game_401671791.csv
# Finished writing to game_401671790.csv
# Finished writing to game_401671784.csv
